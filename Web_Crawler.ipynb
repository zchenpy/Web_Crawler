# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Create-a-list-of-dog-breed's-name-and-their-AKC-webpage" data-toc-modified-id="1.-Create-a-list-of-dog-breed's-name-and-their-AKC-webpage-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>1. Create a list of dog breed's name and their AKC webpage</a></span></li><li><span><a href="#2.-Get-information-of-each-specific-dog-breed" data-toc-modified-id="2.-Get-information-of-each-specific-dog-breed-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>2. Get information of each specific dog breed</a></span></li></ul></div>

# %% [markdown]
# ## 1. Create a list of dog breed's name and their AKC webpage

# %%
# Requirements (use pip to install)
# requests, csv, pandas, bs4, selenium==4.0.0, webdriver-manager

# %%
import requests  # for getting html
import time, os, csv
import pandas as pd  
from selenium import webdriver  # for rendering webpage with javascript 
from selenium.webdriver.chrome.service import Service  # webdriver
from webdriver_manager.chrome import ChromeDriverManager  # webddriver
from bs4 import BeautifulSoup  # for web parsing

# %%
# Get AKC main page to a string
req = requests.get('https://www.akc.org')
akc_main = req.text

# %%
# Convert webpage string to Beutifulsoup object to find the name and link of each breed
soup_main = BeautifulSoup(akc_main, 'html.parser')
breeds = soup_main.find_all('option')  # All breeds' info have the <option> tag
breed_page = {}  # Dictionary key = breed's name, value = breed's page
for dog in breeds[:284]:  # There are total of 283 different types of breeds
    page = dog.get('value')
    name = dog.text
    if name != 'Select A Breed':  # Ignore first element 
        breed_page[name] = page
for name, page in breed_page.items():
    print(name, page)
# Out:
# Affenpinscher https://www.akc.org/dog-breeds/affenpinscher/
# Afghan Hound https://www.akc.org/dog-breeds/afghan-hound/
# Airedale Terrier https://www.akc.org/dog-breeds/airedale-terrier/
# Akita https://www.akc.org/dog-breeds/akita/
# Alaskan Klee Kai https://www.akc.org/dog-breeds/alaskan-klee-kai/
# Alaskan Malamute https://www.akc.org/dog-breeds/alaskan-malamute/
# American Bulldog https://www.akc.org/dog-breeds/american-bulldog/
# American English Coonhound https://www.akc.org/dog-breeds/american-english-coonhound/
# American Eskimo Dog https://www.akc.org/dog-breeds/american-eskimo-dog/
# American Foxhound https://www.akc.org/dog-breeds/american-foxhound/
# American Hairless Terrier https://www.akc.org/dog-breeds/american-hairless-terrier/
# American Leopard Hound https://www.akc.org/dog-breeds/american-leopard-hound/
# American Staffordshire Terrier https://www.akc.org/dog-breeds/american-staffordshire-terrier/
# American Water Spaniel https://www.akc.org/dog-breeds/american-water-spaniel/
# Anatolian Shepherd Dog https://www.akc.org/dog-breeds/anatolian-shepherd-dog/
# Appenzeller Sennenhund https://www.akc.org/dog-breeds/appenzeller-sennenhund/
# Australian Cattle Dog https://www.akc.org/dog-breeds/australian-cattle-dog/
# Australian Kelpie https://www.akc.org/dog-breeds/australian-kelpie/
# Australian Shepherd https://www.akc.org/dog-breeds/australian-shepherd/
# Australian Stumpy Tail Cattle Dog https://www.akc.org/dog-breeds/australian-stumpy-tail-cattle-dog/
# Australian Terrier https://www.akc.org/dog-breeds/australian-terrier/
# Azawakh https://www.akc.org/dog-breeds/azawakh/
# Barbado da Terceira https://www.akc.org/dog-breeds/barbado-da-terceira/
# Barbet https://www.akc.org/dog-breeds/barbet/
# Basenji https://www.akc.org/dog-breeds/basenji/
# Basset Fauve de Bretagne https://www.akc.org/dog-breeds/basset-fauve-de-bretagne/
# Basset Hound https://www.akc.org/dog-breeds/basset-hound/
# Bavarian Mountain Scent Hound https://www.akc.org/dog-breeds/bavarian-mountain-scent-hound/
# Beagle https://www.akc.org/dog-breeds/beagle/
# Bearded Collie https://www.akc.org/dog-breeds/bearded-collie/
# Beauceron https://www.akc.org/dog-breeds/beauceron/
# Bedlington Terrier https://www.akc.org/dog-breeds/bedlington-terrier/
# Belgian Laekenois https://www.akc.org/dog-breeds/belgian-laekenois/
# Belgian Malinois https://www.akc.org/dog-breeds/belgian-malinois/
# Belgian Sheepdog https://www.akc.org/dog-breeds/belgian-sheepdog/
# Belgian Tervuren https://www.akc.org/dog-breeds/belgian-tervuren/
# Bergamasco Sheepdog https://www.akc.org/dog-breeds/bergamasco-sheepdog/
# Berger Picard https://www.akc.org/dog-breeds/berger-picard/
# Bernese Mountain Dog https://www.akc.org/dog-breeds/bernese-mountain-dog/
# Bichon Frise https://www.akc.org/dog-breeds/bichon-frise/
# Biewer Terrier https://www.akc.org/dog-breeds/biewer-terrier/
# Black and Tan Coonhound https://www.akc.org/dog-breeds/black-and-tan-coonhound/
# Black Russian Terrier https://www.akc.org/dog-breeds/black-russian-terrier/
# Bloodhound https://www.akc.org/dog-breeds/bloodhound/
# Bluetick Coonhound https://www.akc.org/dog-breeds/bluetick-coonhound/
# Boerboel https://www.akc.org/dog-breeds/boerboel/
# Bohemian Shepherd https://www.akc.org/dog-breeds/bohemian-shepherd/
# Bolognese https://www.akc.org/dog-breeds/bolognese/
# Border Collie https://www.akc.org/dog-breeds/border-collie/
# Border Terrier https://www.akc.org/dog-breeds/border-terrier/
# Borzoi https://www.akc.org/dog-breeds/borzoi/
# Boston Terrier https://www.akc.org/dog-breeds/boston-terrier/
# Bouvier des Flandres https://www.akc.org/dog-breeds/bouvier-des-flandres/
# Boxer https://www.akc.org/dog-breeds/boxer/
# Boykin Spaniel https://www.akc.org/dog-breeds/boykin-spaniel/
# Bracco Italiano https://www.akc.org/dog-breeds/bracco-italiano/
# Braque du Bourbonnais https://www.akc.org/dog-breeds/braque-du-bourbonnais/
# Braque Francais Pyrenean https://www.akc.org/dog-breeds/braque-francais-pyrenean/
# Briard https://www.akc.org/dog-breeds/briard/
# Brittany https://www.akc.org/dog-breeds/brittany/
# Broholmer https://www.akc.org/dog-breeds/broholmer/
# Brussels Griffon https://www.akc.org/dog-breeds/brussels-griffon/
# Bull Terrier https://www.akc.org/dog-breeds/bull-terrier/
# Bulldog https://www.akc.org/dog-breeds/bulldog/
# Bullmastiff https://www.akc.org/dog-breeds/bullmastiff/
# Cairn Terrier https://www.akc.org/dog-breeds/cairn-terrier/
# Canaan Dog https://www.akc.org/dog-breeds/canaan-dog/
# Cane Corso https://www.akc.org/dog-breeds/cane-corso/
# Cardigan Welsh Corgi https://www.akc.org/dog-breeds/cardigan-welsh-corgi/
# Carolina Dog https://www.akc.org/dog-breeds/carolina-dog/
# Catahoula Leopard Dog https://www.akc.org/dog-breeds/catahoula-leopard-dog/
# Caucasian Shepherd Dog https://www.akc.org/dog-breeds/caucasian-shepherd-dog/
# Cavalier King Charles Spaniel https://www.akc.org/dog-breeds/cavalier-king-charles-spaniel/
# Central Asian Shepherd Dog https://www.akc.org/dog-breeds/central-asian-shepherd-dog/
# Cesky Terrier https://www.akc.org/dog-breeds/cesky-terrier/
# Chesapeake Bay Retriever https://www.akc.org/dog-breeds/chesapeake-bay-retriever/
# Chihuahua https://www.akc.org/dog-breeds/chihuahua/
# Chinese Crested https://www.akc.org/dog-breeds/chinese-crested/
# Chinese Shar-Pei https://www.akc.org/dog-breeds/chinese-shar-pei/
# Chinook https://www.akc.org/dog-breeds/chinook/
# Chow Chow https://www.akc.org/dog-breeds/chow-chow/
# Cirneco dell’Etna https://www.akc.org/dog-breeds/cirneco-delletna/
# Clumber Spaniel https://www.akc.org/dog-breeds/clumber-spaniel/
# Cocker Spaniel https://www.akc.org/dog-breeds/cocker-spaniel/
# Collie https://www.akc.org/dog-breeds/collie/
# Coton de Tulear https://www.akc.org/dog-breeds/coton-de-tulear/
# Croatian Sheepdog https://www.akc.org/dog-breeds/croatian-sheepdog/
# Curly-Coated Retriever https://www.akc.org/dog-breeds/curly-coated-retriever/
# Czechoslovakian Vlcak https://www.akc.org/dog-breeds/czechoslovakian-vlcak/
# Dachshund https://www.akc.org/dog-breeds/dachshund/
# Dalmatian https://www.akc.org/dog-breeds/dalmatian/
# Dandie Dinmont Terrier https://www.akc.org/dog-breeds/dandie-dinmont-terrier/
# Danish-Swedish Farmdog https://www.akc.org/dog-breeds/danish-swedish-farmdog/
# Deutscher Wachtelhund https://www.akc.org/dog-breeds/deutscher-wachtelhund/
# Doberman Pinscher https://www.akc.org/dog-breeds/doberman-pinscher/
# Dogo Argentino https://www.akc.org/dog-breeds/dogo-argentino/
# Dogue de Bordeaux https://www.akc.org/dog-breeds/dogue-de-bordeaux/
# Drentsche Patrijshond https://www.akc.org/dog-breeds/drentsche-patrijshond/
# Drever https://www.akc.org/dog-breeds/drever/
# Dutch Shepherd https://www.akc.org/dog-breeds/dutch-shepherd/
# English Cocker Spaniel https://www.akc.org/dog-breeds/english-cocker-spaniel/
# English Foxhound https://www.akc.org/dog-breeds/english-foxhound/
# English Setter https://www.akc.org/dog-breeds/english-setter/
# English Springer Spaniel https://www.akc.org/dog-breeds/english-springer-spaniel/
# English Toy Spaniel https://www.akc.org/dog-breeds/english-toy-spaniel/
# Entlebucher Mountain Dog https://www.akc.org/dog-breeds/entlebucher-mountain-dog/
# Estrela Mountain Dog https://www.akc.org/dog-breeds/estrela-mountain-dog/
# Eurasier https://www.akc.org/dog-breeds/eurasier/
# Field Spaniel https://www.akc.org/dog-breeds/field-spaniel/
# Finnish Lapphund https://www.akc.org/dog-breeds/finnish-lapphund/
# Finnish Spitz https://www.akc.org/dog-breeds/finnish-spitz/
# Flat-Coated Retriever https://www.akc.org/dog-breeds/flat-coated-retriever/
# French Bulldog https://www.akc.org/dog-breeds/french-bulldog/
# French Spaniel https://www.akc.org/dog-breeds/french-spaniel/
# German Longhaired Pointer https://www.akc.org/dog-breeds/german-longhaired-pointer/
# German Pinscher https://www.akc.org/dog-breeds/german-pinscher/
# German Shepherd Dog https://www.akc.org/dog-breeds/german-shepherd-dog/
# German Shorthaired Pointer https://www.akc.org/dog-breeds/german-shorthaired-pointer/
# German Spitz https://www.akc.org/dog-breeds/german-spitz/
# German Wirehaired Pointer https://www.akc.org/dog-breeds/german-wirehaired-pointer/
# Giant Schnauzer https://www.akc.org/dog-breeds/giant-schnauzer/
# Glen of Imaal Terrier https://www.akc.org/dog-breeds/glen-of-imaal-terrier/
# Golden Retriever https://www.akc.org/dog-breeds/golden-retriever/
# Gordon Setter https://www.akc.org/dog-breeds/gordon-setter/
# Grand Basset Griffon Vendéen https://www.akc.org/dog-breeds/grand-basset-griffon-vendeen/
# Great Dane https://www.akc.org/dog-breeds/great-dane/
# Great Pyrenees https://www.akc.org/dog-breeds/great-pyrenees/
# Greater Swiss Mountain Dog https://www.akc.org/dog-breeds/greater-swiss-mountain-dog/
# Greyhound https://www.akc.org/dog-breeds/greyhound/
# Hamiltonstovare https://www.akc.org/dog-breeds/hamiltonstovare/
# Hanoverian Scenthound https://www.akc.org/dog-breeds/hanoverian-scenthound/
# Harrier https://www.akc.org/dog-breeds/harrier/
# Havanese https://www.akc.org/dog-breeds/havanese/
# Hokkaido https://www.akc.org/dog-breeds/hokkaido/
# Hovawart https://www.akc.org/dog-breeds/hovawart/
# Ibizan Hound https://www.akc.org/dog-breeds/ibizan-hound/
# Icelandic Sheepdog https://www.akc.org/dog-breeds/icelandic-sheepdog/
# Irish Red and White Setter https://www.akc.org/dog-breeds/irish-red-and-white-setter/
# Irish Setter https://www.akc.org/dog-breeds/irish-setter/
# Irish Terrier https://www.akc.org/dog-breeds/irish-terrier/
# Irish Water Spaniel https://www.akc.org/dog-breeds/irish-water-spaniel/
# Irish Wolfhound https://www.akc.org/dog-breeds/irish-wolfhound/
# Italian Greyhound https://www.akc.org/dog-breeds/italian-greyhound/
# Jagdterrier https://www.akc.org/dog-breeds/jagdterrier/
# Japanese Akitainu https://www.akc.org/dog-breeds/japanese-akitainu/
# Japanese Chin https://www.akc.org/dog-breeds/japanese-chin/
# Japanese Spitz https://www.akc.org/dog-breeds/japanese-spitz/
# Japanese Terrier https://www.akc.org/dog-breeds/japanese-terrier/
# Jindo https://www.akc.org/dog-breeds/jindo/
# Kai Ken https://www.akc.org/dog-breeds/kai-ken/
# Karelian Bear Dog https://www.akc.org/dog-breeds/karelian-bear-dog/
# Keeshond https://www.akc.org/dog-breeds/keeshond/
# Kerry Blue Terrier https://www.akc.org/dog-breeds/kerry-blue-terrier/
# Kishu Ken https://www.akc.org/dog-breeds/kishu-ken/
# Komondor https://www.akc.org/dog-breeds/komondor/
# Kromfohrlander https://www.akc.org/dog-breeds/kromfohrlander/
# Kuvasz https://www.akc.org/dog-breeds/kuvasz/
# Labrador Retriever https://www.akc.org/dog-breeds/labrador-retriever/
# Lagotto Romagnolo https://www.akc.org/dog-breeds/lagotto-romagnolo/
# Lakeland Terrier https://www.akc.org/dog-breeds/lakeland-terrier/
# Lancashire Heeler https://www.akc.org/dog-breeds/lancashire-heeler/
# Lapponian Herder https://www.akc.org/dog-breeds/lapponian-herder/
# Leonberger https://www.akc.org/dog-breeds/leonberger/
# Lhasa Apso https://www.akc.org/dog-breeds/lhasa-apso/
# Löwchen https://www.akc.org/dog-breeds/lowchen/
# Maltese https://www.akc.org/dog-breeds/maltese/
# Manchester Terrier (Standard) https://www.akc.org/dog-breeds/manchester-terrier-standard/
# Manchester Terrier (Toy) https://www.akc.org/dog-breeds/manchester-terrier-toy/
# Mastiff https://www.akc.org/dog-breeds/mastiff/
# Miniature American Shepherd https://www.akc.org/dog-breeds/miniature-american-shepherd/
# Miniature Bull Terrier https://www.akc.org/dog-breeds/miniature-bull-terrier/
# Miniature Pinscher https://www.akc.org/dog-breeds/miniature-pinscher/
# Miniature Schnauzer https://www.akc.org/dog-breeds/miniature-schnauzer/
# Mountain Cur https://www.akc.org/dog-breeds/mountain-cur/
# Mudi https://www.akc.org/dog-breeds/mudi/
# Neapolitan Mastiff https://www.akc.org/dog-breeds/neapolitan-mastiff/
# Nederlandse Kooikerhondje https://www.akc.org/dog-breeds/nederlandse-kooikerhondje/
# Newfoundland https://www.akc.org/dog-breeds/newfoundland/
# Norfolk Terrier https://www.akc.org/dog-breeds/norfolk-terrier/
# Norrbottenspets https://www.akc.org/dog-breeds/norrbottenspets/
# Norwegian Buhund https://www.akc.org/dog-breeds/norwegian-buhund/
# Norwegian Elkhound https://www.akc.org/dog-breeds/norwegian-elkhound/
# Norwegian Lundehund https://www.akc.org/dog-breeds/norwegian-lundehund/
# Norwich Terrier https://www.akc.org/dog-breeds/norwich-terrier/
# Nova Scotia Duck Tolling Retriever https://www.akc.org/dog-breeds/nova-scotia-duck-tolling-retriever/
# Old English Sheepdog https://www.akc.org/dog-breeds/old-english-sheepdog/
# Otterhound https://www.akc.org/dog-breeds/otterhound/
# Papillon https://www.akc.org/dog-breeds/papillon/
# Parson Russell Terrier https://www.akc.org/dog-breeds/parson-russell-terrier/
# Pekingese https://www.akc.org/dog-breeds/pekingese/
# Pembroke Welsh Corgi https://www.akc.org/dog-breeds/pembroke-welsh-corgi/
# Perro de Presa Canario https://www.akc.org/dog-breeds/perro-de-presa-canario/
# Peruvian Inca Orchid https://www.akc.org/dog-breeds/peruvian-inca-orchid/
# Petit Basset Griffon Vendéen https://www.akc.org/dog-breeds/petit-basset-griffon-vendeen/
# Pharaoh Hound https://www.akc.org/dog-breeds/pharaoh-hound/
# Plott Hound https://www.akc.org/dog-breeds/plott-hound/
# Pointer https://www.akc.org/dog-breeds/pointer/
# Polish Lowland Sheepdog https://www.akc.org/dog-breeds/polish-lowland-sheepdog/
# Pomeranian https://www.akc.org/dog-breeds/pomeranian/
# Poodle (Miniature) https://www.akc.org/dog-breeds/poodle-miniature/
# Poodle (Standard) https://www.akc.org/dog-breeds/poodle-standard/
# Poodle (Toy) https://www.akc.org/dog-breeds/poodle-toy/
# Porcelaine https://www.akc.org/dog-breeds/porcelaine/
# Portuguese Podengo https://www.akc.org/dog-breeds/portuguese-podengo/
# Portuguese Podengo Pequeno https://www.akc.org/dog-breeds/portuguese-podengo-pequeno/
# Portuguese Pointer https://www.akc.org/dog-breeds/portuguese-pointer/
# Portuguese Sheepdog https://www.akc.org/dog-breeds/portuguese-sheepdog/
# Portuguese Water Dog https://www.akc.org/dog-breeds/portuguese-water-dog/
# Pudelpointer https://www.akc.org/dog-breeds/pudelpointer/
# Pug https://www.akc.org/dog-breeds/pug/
# Puli https://www.akc.org/dog-breeds/puli/
# Pumi https://www.akc.org/dog-breeds/pumi/
# Pyrenean Mastiff https://www.akc.org/dog-breeds/pyrenean-mastiff/
# Pyrenean Shepherd https://www.akc.org/dog-breeds/pyrenean-shepherd/
# Rafeiro do Alentejo https://www.akc.org/dog-breeds/rafeiro-do-alentejo/
# Rat Terrier https://www.akc.org/dog-breeds/rat-terrier/
# Redbone Coonhound https://www.akc.org/dog-breeds/redbone-coonhound/
# Rhodesian Ridgeback https://www.akc.org/dog-breeds/rhodesian-ridgeback/
# Romanian Carpathian Shepherd https://www.akc.org/dog-breeds/romanian-carpathian-shepherd/
# Romanian Mioritic Shepherd Dog https://www.akc.org/dog-breeds/romanian-mioritic-shepherd-dog/
# Rottweiler https://www.akc.org/dog-breeds/rottweiler/
# Russell Terrier https://www.akc.org/dog-breeds/russell-terrier/
# Russian Toy https://www.akc.org/dog-breeds/russian-toy/
# Russian Tsvetnaya Bolonka https://www.akc.org/dog-breeds/russian-tsvetnaya-bolonka/
# Saint Bernard https://www.akc.org/dog-breeds/st-bernard/
# Saluki https://www.akc.org/dog-breeds/saluki/
# Samoyed https://www.akc.org/dog-breeds/samoyed/
# Schapendoes https://www.akc.org/dog-breeds/schapendoes/
# Schipperke https://www.akc.org/dog-breeds/schipperke/
# Scottish Deerhound https://www.akc.org/dog-breeds/scottish-deerhound/
# Scottish Terrier https://www.akc.org/dog-breeds/scottish-terrier/
# Sealyham Terrier https://www.akc.org/dog-breeds/sealyham-terrier/
# Segugio Italiano https://www.akc.org/dog-breeds/segugio-italiano/
# Shetland Sheepdog https://www.akc.org/dog-breeds/shetland-sheepdog/
# Shiba Inu https://www.akc.org/dog-breeds/shiba-inu/
# Shih Tzu https://www.akc.org/dog-breeds/shih-tzu/
# Shikoku https://www.akc.org/dog-breeds/shikoku/
# Siberian Husky https://www.akc.org/dog-breeds/siberian-husky/
# Silky Terrier https://www.akc.org/dog-breeds/silky-terrier/
# Skye Terrier https://www.akc.org/dog-breeds/skye-terrier/
# Sloughi https://www.akc.org/dog-breeds/sloughi/
# Slovakian Wirehaired Pointer https://www.akc.org/dog-breeds/slovakian-wirehaired-pointer/
# Slovensky Cuvac https://www.akc.org/dog-breeds/slovensky-cuvac/
# Slovensky Kopov https://www.akc.org/dog-breeds/slovensky-kopov/
# Small Munsterlander https://www.akc.org/dog-breeds/small-munsterlander/
# Smooth Fox Terrier https://www.akc.org/dog-breeds/smooth-fox-terrier/
# Soft Coated Wheaten Terrier https://www.akc.org/dog-breeds/soft-coated-wheaten-terrier/
# Spanish Mastiff https://www.akc.org/dog-breeds/spanish-mastiff/
# Spanish Water Dog https://www.akc.org/dog-breeds/spanish-water-dog/
# Spinone Italiano https://www.akc.org/dog-breeds/spinone-italiano/
# Stabyhoun https://www.akc.org/dog-breeds/stabyhoun/
# Staffordshire Bull Terrier https://www.akc.org/dog-breeds/staffordshire-bull-terrier/
# Standard Schnauzer https://www.akc.org/dog-breeds/standard-schnauzer/
# Sussex Spaniel https://www.akc.org/dog-breeds/sussex-spaniel/
# Swedish Lapphund https://www.akc.org/dog-breeds/swedish-lapphund/
# Swedish Vallhund https://www.akc.org/dog-breeds/swedish-vallhund/
# Taiwan Dog https://www.akc.org/dog-breeds/taiwan-dog/
# Teddy Roosevelt Terrier https://www.akc.org/dog-breeds/teddy-roosevelt-terrier/
# Thai Ridgeback https://www.akc.org/dog-breeds/thai-ridgeback/
# Tibetan Mastiff https://www.akc.org/dog-breeds/tibetan-mastiff/
# Tibetan Spaniel https://www.akc.org/dog-breeds/tibetan-spaniel/
# Tibetan Terrier https://www.akc.org/dog-breeds/tibetan-terrier/
# Tornjak https://www.akc.org/dog-breeds/tornjak/
# Tosa https://www.akc.org/dog-breeds/tosa/
# Toy Fox Terrier https://www.akc.org/dog-breeds/toy-fox-terrier/
# Transylvanian Hound https://www.akc.org/dog-breeds/transylvanian-hound/
# Treeing Tennessee Brindle https://www.akc.org/dog-breeds/treeing-tennessee-brindle/
# Treeing Walker Coonhound https://www.akc.org/dog-breeds/treeing-walker-coonhound/
# Vizsla https://www.akc.org/dog-breeds/vizsla/
# Volpino Italiano https://www.akc.org/dog-breeds/volpino-italiano/
# Weimaraner https://www.akc.org/dog-breeds/weimaraner/
# Welsh Springer Spaniel https://www.akc.org/dog-breeds/welsh-springer-spaniel/
# Welsh Terrier https://www.akc.org/dog-breeds/welsh-terrier/
# West Highland White Terrier https://www.akc.org/dog-breeds/west-highland-white-terrier/
# Wetterhoun https://www.akc.org/dog-breeds/wetterhoun/
# Whippet https://www.akc.org/dog-breeds/whippet/
# Wire Fox Terrier https://www.akc.org/dog-breeds/wire-fox-terrier/
# Wirehaired Pointing Griffon https://www.akc.org/dog-breeds/wirehaired-pointing-griffon/
# Wirehaired Vizsla https://www.akc.org/dog-breeds/wirehaired-vizsla/
# Working Kelpie https://www.akc.org/dog-breeds/working-kelpie/
# Xoloitzcuintli https://www.akc.org/dog-breeds/xoloitzcuintli/
# Yakutian Laika https://www.akc.org/dog-breeds/yakutian-laika/
# Yorkshire Terrier https://www.akc.org/dog-breeds/yorkshire-terrier/

# %% [markdown]
# ## 2. Get information of each specific dog breed

# %%
# Create an empty dataframe to store data
traits = ['Affectionate With Family', 'Good With Young Children', 'Good With Other Dogs', 
          'Shedding Level', 'Coat Grooming Frequency', 'Drooling Level', 'Coat Type', 'Coat Length', 
          'Openness To Strangers', 'Playfulness Level', 'Watchdog/Protective Nature', 'Adaptability Level', 
          'Trainability Level', 'Energy Level', 'Barking Level', 'Mental Stimulation Needs']
headers = ['Name', 'Height', 'Weight', 'Life Expectancy'] + traits
df_all_breeds = pd.DataFrame(columns = headers)
#print(df_all_breeds)
# Out:
# Empty DataFrame
# Columns: [Name, Height, Weight, Life Expectancy, Affectionate With Family, Good With Young Children, Good With Other Dogs, Shedding Level, Coat Grooming Frequency, Drooling Level, Coat Type, Coat Length, Openness To Strangers, Playfulness Level, Watchdog/Protective Nature, Adaptability Level, Trainability Level, Energy Level, Barking Level, Mental Stimulation Needs]
# Index: []

# %%
# Create an empty csv file with headers to store data
file = 'Sample_data.csv' 
if not os.path.isfile(file):
    with open(file, 'w', newline='') as fileout:
        writer = csv.writer(fileout)
        writer.writerow(headers)

# %%
# Function to find height, weight, life expectancy
def findAttributes(page):  #page needs to be a string
    res = []
    for attr in ['Height: ', 'Weight: ', 'Life Expectancy: ']:
        s = page.find(attr)
        e = page.find('<', s)
        res.append(page[s + len(attr):e])
    return res

# %%
# Check if the file already has some data
df = pd.read_csv(file, usecols=['Name'])
dogs = df['Name'].values.tolist()
#print(dogs)

# Iterate all breads and perform web scrape 
# Use selenium to scrape Javascript website in Chrome and extract complete HTML
count = 0
for dog, webpage in breed_page.items():
    if dog in dogs:  # skip if we already have this breed's info
        continue
    count += 1
    start_time = time.time()
    res = [dog, ]
    
    options = webdriver.ChromeOptions()  # create a option for chrome
    options.headless = True  # use headless browser
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options = options)
    #driver = webdriver.Chrome(options = options)
    driver.get(webpage) # extract complete HTML to driver.page_source
    time.sleep(0.5)
    
    # Get Height, Weight and Life Expectancy
    soup = BeautifulSoup(driver.page_source, 'lxml')
    attributes = findAttributes(str(soup))
    res.extend(attributes)

    # Find trait scores
    tag = soup.find_all('div', class_ = "accordion__header__content")
    for e in tag:
        # For coat type and coat length, search for check mark
        check_mark = e.find('div', class_ = 'breed-trait-score__choice--selected')
        if check_mark:
            type_ = check_mark.find('span')
            if type_:
                res.append(type_.text)
            continue
            
        # For other traits, search for score-unit--filled (score bars)
        s = e.find_all('div', class_= 'breed-trait-score__score-unit breed-trait-score__score-unit--filled')
        score = len(s)
        res.append(score)
        
    # Handle errors (can also use autofill instead)
    if len(res) < 20:
        print(res)
        print('Invalid data for {}'.format(dog))
        break
        
    # Append new data to dataframe    
    new_data = pd.Series(res, index = df_all_breeds.columns)
    df_all_breeds = df_all_breeds.append(new_data, ignore_index=True)
    
    # Write data to csv file
    with open(file, 'a', newline = '') as fileout:
        writer = csv.writer(fileout)
        writer.writerow(res)

    print('No.{} {} completed after {} sec'.format(count, dog, round(time.time() - start_time, 3)))

driver.quit()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/cathychen/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# No.1 Affenpinscher completed after 28.229 sec
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/cathychen/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# No.2 Afghan Hound completed after 25.89 sec
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/cathychen/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# No.3 Airedale Terrier completed after 26.803 sec
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/cathychen/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# No.4 Akita completed after 93.707 sec
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/cathychen/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# No.5 Yorkshire Terrier completed after 24.619 sec

# %%
df_all_breeds

# %%
ls
# Out:
# Sample_data.csv    Web_Crawler.ipynb

# %%
df = pd.read_csv('Sample_data.csv')

# %%
df
# Out:
#                   Name                                             Height  \
# 0        Affenpinscher                                      9-11.5 inches
# 1         Afghan Hound                                       25-27 inches
# 2     Airedale Terrier                                          23 inches
# 3                Akita         26-28 inches (male), 24-26 inches (female)
# 4     Alaskan Klee Kai  13 inches and under (Toy), 13-15 inches (Minia...
# ..                 ...                                                ...
# 278  Wirehaired Vizsla       23-25 inches (male), 21.5-23 inches (female)
# 279     Working Kelpie                                       19-25 inches
# 280     Xoloitzcuintli  10-14 inches (toy), 14-18 inches (miniature), ...
# 281     Yakutian Laika                                       21-23 inches
# 282  Yorkshire Terrier                                         7-8 inches
#
#                                                 Weight Life Expectancy  \
# 0                                          7-10 pounds     12-15 years
# 1                                         50-60 pounds     12-15 years
# 2                                         50-70 pounds     11-14 years
# 3        100-130 pounds (male), 70-100 pounds (female)     10-13 years
# 4    6-12 lbs (Toy), 10-18 lbs (Miniature), 16-25 l...     13-16 years
# ..                                                 ...             ...
# 278         55-65 pounds (male), 45-55 pounds (female)     12-14 years
# 279                                       28-60 pounds     12-15 years
# 280  10-15 pounds (toy), 15-30 pounds (miniature), ...     13-18 years
# 281                                       40-55 pounds     10-12 years
# 282                                           7 pounds     11-15 years
#
#      Affectionate With Family  Good With Young Children  Good With Other Dogs  \
# 0                           3                         3                     3
# 1                           3                         3                     3
# 2                           3                         3                     3
# 3                           3                         3                     1
# 4                           3                         3                     5
# ..                        ...                       ...                   ...
# 278                         5                         5                     3
# 279                         5                         5                     3
# 280                         5                         3                     3
# 281                         5                         5                     4
# 282                         5                         5                     3
#
#      Shedding Level  Coat Grooming Frequency  Drooling Level Coat Type  \
# 0                 3                        3               1      Wiry
# 1                 1                        4               1     Silky
# 2                 1                        3               1      Wiry
# 3                 3                        3               1    Double
# 4                 3                        3               1    Double
# ..              ...                      ...             ...       ...
# 278               3                        1               2      Wiry
# 279               3                        1               2    Smooth
# 280               1                        1               1  Hairless
# 281               4                        2               3    Double
# 282               1                        5               1     Silky
#
#     Coat Length  Openness To Strangers  Playfulness Level  \
# 0         Short                      5                  3
# 1          Long                      3                  3
# 2         Short                      3                  3
# 3        Medium                      2                  3
# 4        Medium                      1                  3
# ..          ...                    ...                ...
# 278       Short                      5                  5
# 279       Short                      5                  5
# 280       Short                      3                  4
# 281      Medium                      1                  4
# 282        Long                      5                  4
#
#      Watchdog/Protective Nature  Adaptability Level  Trainability Level  \
# 0                             3                   4                   3
# 1                             3                   3                   1
# 2                             5                   3                   3
# 3                             5                   3                   3
# 4                             3                   3                   3
# ..                          ...                 ...                 ...
# 278                           3                   4                   5
# 279                           4                   4                   5
# 280                           3                   4                   4
# 281                           5                   4                   3
# 282                           5                   5                   4
#
#      Energy Level  Barking Level  Mental Stimulation Needs
# 0               3              3                         3
# 1               4              3                         3
# 2               3              3                         3
# 3               4              2                         3
# 4               3              3                         3
# ..            ...            ...                       ...
# 278             5              3                         5
# 279             5              3                         5
# 280             4              3                         4
# 281             5              4                         5
# 282             4              4                         4
#
# [283 rows x 20 columns]
